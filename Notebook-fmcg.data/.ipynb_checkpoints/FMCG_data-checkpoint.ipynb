# %%
import kagglehub 
import pandas as pd
import os
path = kagglehub.dataset_download("beatafaron/fmcg-daily-sales-data-to-2022-2024")
# 2. Xem trong đó có file gì (thường là file .csv)
files = os.listdir(path)
print("Các file tìm thấy:", files)

# 3. Đọc file đầu tiên vào Pandas để làm việc luôn
# Giả sử file có tên là 'fmcg_data.csv' (bạn thay tên file thật vào đây nhé)
file_path = os.path.join(path, files[0]) 
df = pd.read_csv(file_path)

# 4. Xem thử 5 dòng đầu
df.head()
